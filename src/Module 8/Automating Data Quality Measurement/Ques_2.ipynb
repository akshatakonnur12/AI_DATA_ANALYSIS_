# %% [markdown]
# ### Task 1: Validate Data with a Custom Expectation in Great Expectations
# **Description**: Create a custom expectation and validate data with Great Expectations.
#
# **Load a sample DataFrame**
#
# data = {
# 'age': [25, 30, 35, 40, 45],
# 'income': [50000, 60000, 75000, None, 100000]
# }

# %%
# Write your code from here

# %%
import pandas as pd
from great_expectations.validator.validator import Validator
from great_expectations.expectations.expectation import ExpectationConfiguration
from great_expectations.core.batch import Batch
from great_expectations.core.batch import BatchRequest, RuntimeBatchRequest
from great_expectations.data_context import get_context

data={'age':[25,30,35,40,45],'income':[50000,60000,75000,None,100000]}
df=pd.DataFrame(data)
context=get_context()
batch_request=RuntimeBatchRequest(
    datasource_name="my_pandas_datasource",
    data_connector_name="default_runtime_data_connector_name",
    data_asset_name="test_asset",
    runtime_parameters={"batch_data": df},
    batch_identifiers={"default_identifier_name": "default_id"}
)
validator=context.get_validator(batch_request=batch_request)
result=validator.expect_column_values_to_not_be_null("income")
print(result)
# Out:
# ---------------------------------------------------------------------------
# DatasourceError                           Traceback (most recent call last)
# Cell In[2], line 18
#      10 context=get_context()
#      11 batch_request=RuntimeBatchRequest(
#      12     datasource_name="my_pandas_datasource",
#      13     data_connector_name="default_runtime_data_connector_name",
#    (...)
#      16     batch_identifiers={"default_identifier_name": "default_id"}
#      17 )
# ---> 18 validator=context.get_validator(batch_request=batch_request)
#      19 result=validator.expect_column_values_to_not_be_null("income")
#      20 print(result)
#
# File ~/.local/lib/python3.10/site-packages/great_expectations/data_context/data_context/abstract_data_context.py:1159, in AbstractDataContext.get_validator(self, datasource_name, data_connector_name, data_asset_name, batch, batch_list, batch_request, batch_request_list, batch_data, data_connector_query, batch_identifiers, limit, index, custom_filter_function, sampling_method, sampling_kwargs, partitioner_method, partitioner_kwargs, runtime_parameters, query, path, batch_filter_parameters, batch_spec_passthrough, expectation_suite_id, expectation_suite_name, expectation_suite, create_expectation_suite_with_name, **kwargs)
#    1100 """Retrieve a Validator with a batch list and an `ExpectationSuite`.
#    1101
#    1102 `get_validator` first calls `get_batch_list` to retrieve a batch list, then creates or retrieves
#    (...)
#    1151         retrieved using either the provided name or identifier
#    1152 """  # noqa: E501 # FIXME CoP
#    1153 expectation_suite = self._get_expectation_suite_from_inputs(
#    1154     expectation_suite=expectation_suite,
#    1155     expectation_suite_name=expectation_suite_name,
#    1156     create_expectation_suite_with_name=create_expectation_suite_with_name,
#    1157     expectation_suite_id=expectation_suite_id,
#    1158 )
# -> 1159 batch_list = self._get_batch_list_from_inputs(
#    1160     datasource_name=datasource_name,
#    1161     data_connector_name=data_connector_name,
#    1162     data_asset_name=data_asset_name,
#    1163     batch=batch,
#    1164     batch_list=batch_list,
#    1165     batch_request=batch_request,
#    1166     batch_request_list=batch_request_list,
#    1167     batch_data=batch_data,
#    1168     data_connector_query=data_connector_query,
#    1169     batch_identifiers=batch_identifiers,
#    1170     limit=limit,
#    1171     index=index,
#    1172     custom_filter_function=custom_filter_function,
#    1173     sampling_method=sampling_method,
#    1174     sampling_kwargs=sampling_kwargs,
#    1175     partitioner_method=partitioner_method,
#    1176     partitioner_kwargs=partitioner_kwargs,
#    1177     runtime_parameters=runtime_parameters,
#    1178     query=query,
#    1179     path=path,
#    1180     batch_filter_parameters=batch_filter_parameters,
#    1181     batch_spec_passthrough=batch_spec_passthrough,
#    1182     **kwargs,
#    1183 )
#    1184 return self.get_validator_using_batch_list(
#    1185     expectation_suite=expectation_suite,
#    1186     batch_list=batch_list,
#    1187 )
#
# File ~/.local/lib/python3.10/site-packages/great_expectations/data_context/data_context/abstract_data_context.py:1244, in AbstractDataContext._get_batch_list_from_inputs(self, datasource_name, data_connector_name, data_asset_name, batch, batch_list, batch_request, batch_request_list, batch_data, data_connector_query, batch_identifiers, limit, index, custom_filter_function, sampling_method, sampling_kwargs, partitioner_method, partitioner_kwargs, runtime_parameters, query, path, batch_filter_parameters, batch_spec_passthrough, **kwargs)
#    1241     batch_request_list = [batch_request]  # type: ignore[list-item] # FIXME CoP
#    1242 for batch_req in batch_request_list:
#    1243     computed_batch_list.append(
# -> 1244         self.get_last_batch(
#    1245             datasource_name=datasource_name,
#    1246             data_connector_name=data_connector_name,
#    1247             data_asset_name=data_asset_name,
#    1248             batch_request=batch_req,
#    1249             batch_data=batch_data,
#    1250             data_connector_query=data_connector_query,
#    1251             batch_identifiers=batch_identifiers,
#    1252             limit=limit,
#    1253             index=index,
#    1254             custom_filter_function=custom_filter_function,
#    1255             sampling_method=sampling_method,
#    1256             sampling_kwargs=sampling_kwargs,
#    1257             partitioner_method=partitioner_method,
#    1258             partitioner_kwargs=partitioner_kwargs,
#    1259             runtime_parameters=runtime_parameters,
#    1260             query=query,
#    1261             path=path,
#    1262             batch_filter_parameters=batch_filter_parameters,
#    1263             batch_spec_passthrough=batch_spec_passthrough,
#    1264             **kwargs,
#    1265         )
#    1266     )
#    1267 return computed_batch_list
#
# File ~/.local/lib/python3.10/site-packages/great_expectations/data_context/data_context/abstract_data_context.py:1437, in AbstractDataContext.get_last_batch(self, datasource_name, data_connector_name, data_asset_name, batch_request, batch_data, data_connector_query, batch_identifiers, limit, index, custom_filter_function, sampling_method, sampling_kwargs, partitioner_method, partitioner_kwargs, runtime_parameters, query, path, batch_filter_parameters, batch_spec_passthrough, batch_parameters, **kwargs)
#    1364 def get_last_batch(  # noqa: PLR0913 # FIXME CoP
#    1365     self,
#    1366     datasource_name: Optional[str] = None,
#    (...)
#    1386     **kwargs: Optional[dict],
#    1387 ) -> Batch:
#    1388     """Get the list of zero or more batches, based on a variety of flexible input types.
#    1389
#    1390     `get_batch_list` is the main user-facing API for getting batches.
#    (...)
#    1435
#    1436     """  # noqa: E501 # FIXME CoP
# -> 1437     return self._get_last_batch(
#    1438         datasource_name=datasource_name,
#    1439         data_connector_name=data_connector_name,
#    1440         data_asset_name=data_asset_name,
#    1441         batch_request=batch_request,
#    1442         batch_data=batch_data,
#    1443         data_connector_query=data_connector_query,
#    1444         batch_identifiers=batch_identifiers,
#    1445         limit=limit,
#    1446         index=index,
#    1447         custom_filter_function=custom_filter_function,
#    1448         sampling_method=sampling_method,
#    1449         sampling_kwargs=sampling_kwargs,
#    1450         partitioner_method=partitioner_method,
#    1451         partitioner_kwargs=partitioner_kwargs,
#    1452         runtime_parameters=runtime_parameters,
#    1453         query=query,
#    1454         path=path,
#    1455         batch_filter_parameters=batch_filter_parameters,
#    1456         batch_spec_passthrough=batch_spec_passthrough,
#    1457         batch_parameters=batch_parameters,
#    1458         **kwargs,
#    1459     )
#
# File ~/.local/lib/python3.10/site-packages/great_expectations/data_context/data_context/abstract_data_context.py:1512, in AbstractDataContext._get_last_batch(self, datasource_name, data_connector_name, data_asset_name, batch_request, batch_data, data_connector_query, batch_identifiers, limit, index, custom_filter_function, sampling_method, sampling_kwargs, partitioner_method, partitioner_kwargs, runtime_parameters, query, path, batch_filter_parameters, batch_spec_passthrough, batch_parameters, **kwargs)
#    1510 datasource = self.data_sources.all().get(datasource_name)
#    1511 if not datasource:
# -> 1512     raise gx_exceptions.DatasourceError(
#    1513         datasource_name,
#    1514         "The given datasource could not be retrieved from the DataContext; "
#    1515         "please confirm that your configuration is accurate.",
#    1516     )
#    1518 return datasource.get_batch(batch_request=result)
#
# DatasourceError: Cannot initialize datasource my_pandas_datasource, error: The given datasource could not be retrieved from the DataContext; please confirm that your configuration is accurate.

# %% [markdown]
# ### Task 2: Implement a Basic Alert System for Data Quality Drops
# **Description**: Set up a basic alert system that triggers when data quality drops.

# %%
# Write your code from here

# %% [markdown]
# ### Task 3: Real-time Data Quality Monitoring with Python and Great Expectations
# **Description**: Implement a system that monitors data quality in real-time.

# %%
# Write your code from here
