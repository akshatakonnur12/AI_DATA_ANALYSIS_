# %%
# Part 1: Detect & Handle Missing Data

# Task 1: Detect Missing Data
#     1. Load the Data:
#     2. Detect Missing Data:
import pandas as pd
import numpy as np

# Sample DataFrame with missing values
data = {
    'Name': ['Alice', 'Bob', 'Charlie', None, 'Emily'],
    'Age': [24, np.nan, 22, 25, np.nan],
    'Score': [85, 90, np.nan, 88, 95]
}
df = pd.DataFrame(data)
# Check for missing values
print(df.isnull())
# Count missing values per column
print(df.isnull().sum())




# Task 2: Handle Missing Data by Dropping
#     1. Drop Rows with Missing Values:
df_dropped_any = df.dropna()
print(df_dropped_any)
# Drop rows where all elements are missing
df_dropped_all = df.dropna(how='all')
print(df_dropped_all)
# Drop columns with any missing values
df_dropped_columns = df.dropna(axis=1)
print(df_dropped_columns)
             
        

# Task 3: Handle Missing Data by Imputation
#     1. Fill Missing Values:
df_filled = df.fillna(0)
print(df_filled)
# Forward fill
df_ffill = df.fillna(method='ffill')
print(df_ffill)
# Backward fill
df_bfill = df.fillna(method='bfill')
print(df_bfill)
# Fill missing values in 'Age' column with mean
df['Age'] = df['Age'].fillna(df['Age'].mean())

# Fill missing values in 'Score' column with mean
df['Score'] = df['Score'].fillna(df['Score'].mean())

print(df)
# Out:
#     Name    Age  Score
# 0  False  False  False
# 1  False   True  False
# 2  False  False   True
# 3   True  False  False
# 4  False   True  False
# Name     1
# Age      2
# Score    1
# dtype: int64
#     Name   Age  Score
# 0  Alice  24.0   85.0
#       Name   Age  Score
# 0    Alice  24.0   85.0
# 1      Bob   NaN   90.0
# 2  Charlie  22.0    NaN
# 3     None  25.0   88.0
# 4    Emily   NaN   95.0
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]
#       Name   Age  Score
# 0    Alice  24.0   85.0
# 1      Bob   0.0   90.0
# 2  Charlie  22.0    0.0
# 3        0  25.0   88.0
# 4    Emily   0.0   95.0
#       Name   Age  Score
# 0    Alice  24.0   85.0
# 1      Bob  24.0   90.0
# 2  Charlie  22.0   90.0
# 3  Charlie  25.0   88.0
# 4    Emily  25.0   95.0
#       Name   Age  Score
# 0    Alice  24.0   85.0
# 1      Bob  22.0   90.0
# 2  Charlie  22.0   88.0
# 3    Emily  25.0   88.0
# 4    Emily   NaN   95.0
#       Name        Age  Score
# 0    Alice  24.000000   85.0
# 1      Bob  23.666667   90.0
# 2  Charlie  22.000000   89.5
# 3     None  25.000000   88.0
# 4    Emily  23.666667   95.0
# /tmp/ipykernel_1618/3789960663.py:42: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_ffill = df.fillna(method='ffill')
# /tmp/ipykernel_1618/3789960663.py:45: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_bfill = df.fillna(method='bfill')
